# %% [markdown]
# <a href="https://colab.research.google.com/github/subash-scorpian/Car-sales-analysis/blob/main/Car_sales_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Adding pandas to extract the data
import pandas as pd
#Import car sales csv file to pandas as dataframe(df)
df=pd.read_csv('/Car_sales.csv')

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
# Count missing values in each column
missing_data = df.isnull().sum()

# Calculate the percentage of missing data
missing_data_percentage = (missing_data / len(df)) * 100

# Combine into a DataFrame for better readability
missing_summary = pd.DataFrame({
    'Missing Values': missing_data,
    'Percentage Missing': missing_data_percentage
})

# Filter to only show columns with missing values
missing_summary = missing_summary[missing_summary['Missing Values'] > 0]

# Display the results
print(missing_summary)
# Out:
#                      Missing Values  Percentage Missing
# __year_resale_value              36           22.929936
# Price_in_thousands                2            1.273885
# Engine_size                       1            0.636943
# Horsepower                        1            0.636943
# Wheelbase                         1            0.636943
# Width                             1            0.636943
# Length                            1            0.636943
# Curb_weight                       2            1.273885
# Fuel_capacity                     1            0.636943
# Fuel_efficiency                   3            1.910828
# Power_perf_factor                 2            1.273885

# %%
#What are the average, minimum, and maximum sales in thousands.

# %%
 sales_status = {
    'Average Sales': df['Sales_in_thousands'].mean(),
    'Minimum Sales': df['Sales_in_thousands'].min(),
    'Maximum Sales': df['Sales_in_thousands'].max()}

# %%
sales_status
# Out:
# {'Average Sales': 52.99807643312102,
#  'Minimum Sales': 0.11,
#  'Maximum Sales': 540.561}
